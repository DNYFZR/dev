# %%
import re, numpy as np, pandas as pd

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
url = 'https://raw.githubusercontent.com/JeffSackmann/tennis_MatchChartingProject/master/charting-m-points.csv'
df = pd.read_csv(url, encoding='latin-1', low_memory=False)

# Add tourney date
df['date'] = pd.to_datetime([i.split('-')[0] for i in df['match_id']])

# Add player names
names_tuple = [(i.split('-')[-2].replace('_', ' '), i.split('-')[-1].replace('_', ' '), i.split('-')[-3]) for i in df['match_id']]
df['P1'] = [i[0] for i in names_tuple]
df['P2'] = [i[1] for i in names_tuple]

# Add round
df['round'] = [i[2] for i in names_tuple]

# Add point winner & loser name
df['pointWinner'] = df.apply(lambda row: row['P1'] if row['PtWinner'] == 1 else row['P2'] if row['PtWinner'] == 2 else np.nan, axis=1)
df['pointLoser'] = df.apply(lambda row: row['P2'] if row['PtWinner'] == 1 else row['P1'] if row['PtWinner'] == 2 else np.nan, axis=1)

df.head(2)
# Out:
#                                          match_id  Pt  Set1  Set2  Gm1  Gm2  \
# 0  20220713-M-Newport-R16-Andy_Murray-Max_Purcell   1     0     0  0.0  0.0
# 1  20220713-M-Newport-R16-Andy_Murray-Max_Purcell   2     0     0  0.0  0.0
#
#     Pts    Gm# TbSet TB?  TBpt  Svr  Ret Serving 1st  2nd  \
# 0   0-0  1 (1)     1   0   NaN    1    2      AM   S  NaN
# 1  15-0  1 (2)     1   0   NaN    1    2      AM   S  NaN
#
#                                  Notes  1stSV  2ndSV  1stIn  2ndIn  isAce  \
# 0                                  NaN      0    NaN      0    NaN  False
# 1  Video feed froze for first 2 points      0    NaN      0    NaN  False
#
#    isUnret  isRallyWinner  isForced  isUnforced  isDouble  PtWinner  \
# 0    False          False     False       False     False         1
# 1    False          False     False       False     False         1
#
#    isSvrWinner rallyCount       date           P1           P2 round  \
# 0            1          1 2022-07-13  Andy Murray  Max Purcell   R16
# 1            1          1 2022-07-13  Andy Murray  Max Purcell   R16
#
#    pointWinner   pointLoser
# 0  Andy Murray  Max Purcell
# 1  Andy Murray  Max Purcell

# %%
# Match Stats
wins = df.groupby(['match_id', 'pointWinner', 'round'])[['isRallyWinner', ]].sum()
errs = df.drop(columns=['pointWinner']).rename(columns={'pointLoser': 'pointWinner'}).groupby(['match_id', 'pointWinner', 'round'])[[ 'isUnforced', ]].sum()

stats = wins.join(errs, how='outer').reset_index()

stats['Ratio'] = stats['isRallyWinner'] / stats['isUnforced']
stats['Year'] = [int(i[:4]) for i in stats['match_id']]
stats['Tournament'] = [i.split('-')[2].replace('_', ' ').title() for i in stats['match_id']]
stats = stats.rename(columns={'pointWinner': 'Player', 'round': 'Round', 'isRallyWinner': 'Winner', 'isUnforced': 'Unf Error'})

stats.sample(10)
# Out:
#                                                match_id  \
# 236   19870605-M-Roland_Garros-SF-Miloslav_Mecir-Iva...
# 6223  20210113-M-Antalya-F-Alex_De_Minaur-Alexander_...
# 2176  20080420-M-Monte_Carlo_Masters-F-Rafael_Nadal-...
# 2182  20080511-M-Hamburg_Masters-F-Roger_Federer-Raf...
# 2650  20111122-M-Tour_Finals-RR-Roger_Federer-Rafael...
# 7148  20220605-M-Roland_Garros-F-Rafael_Nadal-Casper...
# 211      19860907-M-US_Open-F-Miloslav_Mecir-Ivan_Lendl
# 2711  20120406-M-Davis_Cup_World_Group_QF-RR-Ivo_Kar...
# 6369  20210507-M-Madrid_Masters-QF-John_Isner-Domini...
# 700   19940305-M-Indian_Wells_Masters-SF-Aaron_Krick...
#
#                      Player Round  Winner  Unf Error     Ratio  Year  \
# 236              Ivan Lendl    SF    21.0       33.0  0.636364  1987
# 6223       Alexander Bublik     F     2.0        3.0  0.666667  2021
# 2176           Rafael Nadal     F    13.0       16.0  0.812500  2008
# 2182           Rafael Nadal     F    30.0       21.0  1.428571  2008
# 2650           Rafael Nadal    RR     3.0       15.0  0.200000  2011
# 7148            Casper Ruud     F    15.0       31.0  0.483871  2022
# 211          Miloslav Mecir     F    14.0       45.0  0.311111  1986
# 2711  Juan Martin Del Potro    RR    14.0       12.0  1.166667  2012
# 6369             John Isner    QF    25.0       35.0  0.714286  2021
# 700        Aaron Krickstein    SF     3.0       12.0  0.250000  1994
#
#                     Tournament
# 236              Roland Garros
# 6223                   Antalya
# 2176       Monte Carlo Masters
# 2182           Hamburg Masters
# 2650               Tour Finals
# 7148             Roland Garros
# 211                    Us Open
# 2711  Davis Cup World Group Qf
# 6369            Madrid Masters
# 700       Indian Wells Masters

# %%
# Player
player = [ 'Carlos Alcaraz' ]
rnd = 'F'
tournament = ['Australian Open', 'Roland Garros', 'Wimbledon', 'US Open', 'Madrid Masters']

stats[
    (stats['Player'].isin(player)) & 
    (stats['Round'] ==  rnd.upper()) &
    (stats['Tournament'].isin(tournament))
    ].sort_values('Year')
# Out:
#                                                match_id          Player Round  \
# 7079  20220508-M-Madrid_Masters-F-Carlos_Alcaraz-Ale...  Carlos Alcaraz     F
#
#       Winner  Unf Error     Ratio  Year      Tournament
# 7079    12.0       14.0  0.857143  2022  Madrid Masters
